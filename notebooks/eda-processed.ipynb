# %%
import pandas as pd

# %%
df = pd.read_parquet("gs://cyberbully-data-preparation/cyberbully-bucket-3/data/processed/rebalanced_splits/train.parquet")
# Out:
# ---------------------------------------------------------------------------
# ArrowException                            Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 df = pd.read_parquet("gs://cyberbully-data-preparation/cyberbully-bucket-3/data/processed/rebalanced_splits/train.parquet")
#
# File ~/venv/lib/python3.10/site-packages/pandas/io/parquet.py:670, in read_parquet(path, engine, columns, storage_options, use_nullable_dtypes, dtype_backend, filesystem, filters, **kwargs)
#     667     use_nullable_dtypes = False
#     668 check_dtype_backend(dtype_backend)
# --> 670 return impl.read(
#     671     path,
#     672     columns=columns,
#     673     filters=filters,
#     674     storage_options=storage_options,
#     675     use_nullable_dtypes=use_nullable_dtypes,
#     676     dtype_backend=dtype_backend,
#     677     filesystem=filesystem,
#     678     **kwargs,
#     679 )
#
# ...

# %%
df =pd.read_parquet("https://storage.cloud.google.com/cyberbully-bucket-3/data/processed/rebalanced_splits/train.parquet?authuser=1")
# Out:
# ---------------------------------------------------------------------------
# ArrowInvalid                              Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df =pd.read_parquet("https://storage.cloud.google.com/cyberbully-bucket-3/data/processed/rebalanced_splits/train.parquet?authuser=1")
#
# File ~/venv/lib/python3.10/site-packages/pandas/io/parquet.py:670, in read_parquet(path, engine, columns, storage_options, use_nullable_dtypes, dtype_backend, filesystem, filters, **kwargs)
#     667     use_nullable_dtypes = False
#     668 check_dtype_backend(dtype_backend)
# --> 670 return impl.read(
#     671     path,
#     672     columns=columns,
#     673     filters=filters,
#     674     storage_options=storage_options,
#     675     use_nullable_dtypes=use_nullable_dtypes,
#     676     dtype_backend=dtype_backend,
#     677     filesystem=filesystem,
#     678     **kwargs,
#     679 )
#
# ...
